# %% [markdown]
# ### 1. Write a python program to display all the header tags from‘en.wikipedia.org/wiki/Main_Page’.

# %%
# !pip install bs4
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
url=requests.get("https://en.wikipedia.org/wiki/Main_Page")

# %%
url.status_code
# Out:
# 200

# %%
Soup=BeautifulSoup(url.text,"html.parser")

# %%
story=Soup.find_all(['h1','h2','h3'])

# %%
for i in story:
    print(i)
# Out:
# <h1 class="firstHeading" id="firstHeading">Main Page</h1>
# <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>
# <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>
# <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>
# <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>
# <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>
# <h2 class="mp-h2" id="mp-other"><span class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span></h2>
# ...

# %% [markdown]
# ###  2. Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. Name, IMDB rating, Year of release.

# %%
from requests import get

# %%
url=get("https://www.imdb.com/search/title/?count=100&groups=top_1000&sort=user_rating")

# %%
request=url.text

# %%
from bs4 import BeautifulSoup as Soup

# %%
soup_data=Soup(request,"html.parser")

# %%
soup_data.title.text
# Out:
# 'IMDb "Top 1000"\n(Sorted by IMDb Rating Descending) - IMDb'

# %%
movies=soup_data.findAll('div',{'class':"lister-item mode-advanced"})

# %%
first_movies=movies[0]

# %%
first_movies.h3.a.text
# Out:
# 'The Shawshank Redemption'

# %%
first_movies.find('span',{'class':"lister-item-year text-muted unbold"}).text[1:5]
# Out:
# '1994'

# %%
first_movies.find('div',{'class':"inline-block ratings-imdb-rating"})['data-value']
# Out:
# '9.3'

# %%
Name=[]
Rating=[]
Year=[]
for i in movies:
    Name.append(i.h3.a.text)
    Rating.append(i.find('span',{"class":"lister-item-year text-muted unbold"}).text[1:5])
    Year.append(i.find('div',{"class":"inline-block ratings-imdb-rating"})['data-value'])

# %%
Name
# Out:
# ['The Shawshank Redemption',
#  'The Godfather',
#  'Soorarai Pottru',
#  'The Dark Knight',
#  'The Godfather: Part II',
#  '12 Angry Men',
#  'The Lord of the Rings: The Return of the King',
#  'Pulp Fiction',
#  "Schindler's List",
#  'Inception',
#  'Dara iz Jasenovca',
#  'Fight Club',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'Forrest Gump',
#  'Il buono, il brutto, il cattivo',
#  'Shershaah',
#  'The Lord of the Rings: The Two Towers',
#  'The Matrix',
#  'Goodfellas',
#  'Star Wars: Episode V - The Empire Strikes Back',
#  "One Flew Over the Cuckoo's Nest",
#  'Gisaengchung',
#  'Drishyam 2',
#  'Interstellar',
#  'Cidade de Deus',
#  'Sen to Chihiro no kamikakushi',
#  'Saving Private Ryan',
#  'The Green Mile',
#  'La vita è bella',
#  'Se7en',
#  'The Silence of the Lambs',
#  'Star Wars',
#  'Seppuku',
#  'Shichinin no samurai',
#  "It's a Wonderful Life",
#  'Whiplash',
#  'The Intouchables',
#  'The Prestige',
#  'The Departed',
#  'The Pianist',
# ...

# %%
data=list(zip(Name,Rating,Year))

# %%
import pandas as pd
df=pd.DataFrame(data,columns=['Name','IMDB Rating','Year of Release'])
df.head()
# Out:
#                        Name IMDB Rating Year of Release
# 0  The Shawshank Redemption        1994             9.3
# 1             The Godfather        1972             9.2
# 2           Soorarai Pottru        2020             9.1
# 3           The Dark Knight        2008               9
# 4    The Godfather: Part II        1974               9

# %%
len(df)
# Out:
# 100

# %% [markdown]
# ### 3. Write a python program to display IMDB’s Top rated 100 Indian movies’ data (i.e. Name, IMDB rating, Year

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import re

# %%
# Download IMDB's Top 250 Indian Movies Data
url = 'https://www.imdb.com/india/top-rated-indian-movies/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

movies = soup.select('td.titleColumn')
links = [a.attrs.get('href') for a in soup.select('td.titleColumn a')]

ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]

# %%
Ranking = []
Name = []
Year = []
Rating = []

for index in range(0, len(movies)):
    # Seperate movie into: 'place', 'title', 'year'
    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
    year = re.search('\((.*?)\)', movie_string).group(1)
    place = movie[:len(str(index))-(len(movie))]
    Ranking.append(index+1)
    Name.append(movie_title)
    Year.append(year)
    Rating.append(ratings[index])

# %%
data = list(zip(Ranking, Name, Year, Rating))
df = pd.DataFrame(data,columns=['Ranking', 'Name','Year','Rating'])
df['Rating'] = df['Rating'].astype('float64')
df['Rating'] = df['Rating'].round(decimals=1)

# %%
# Top 100 indiab movies
df[:100]
# Out:
#     Ranking                                Name  Year  Rating
# 0         1                             Nayakan  1987     8.5
# 1         2                          Anbe Sivam  2003     8.5
# 2         3                   Pariyerum Perumal  2018     8.5
# 3         4                   C/o Kancharapalem  2018     8.5
# 4         5                             Golmaal  1979     8.5
# ..      ...                                 ...   ...     ...
# 95       96                     Rang De Basanti  2006     8.1
# 96       97                     OMG: Oh My God!  2012     8.1
# 97       98                                Roja  1992     8.1
# 98       99            Uri: The Surgical Strike  2019     8.1
# 99      100   Lagaan: Once Upon a Time in India  2001     8.1
#
# [100 rows x 4 columns]

# %%
# Save 100 records to a csv file
# df[:100].to_csv('top_100_indian_movies.csv', header=True, index=False)

# %% [markdown]
# ### 4. Write a python program to scrap book name, author name, genre and book review of any 5 books from

# %%
from requests import get

# %%
url=get("https://bookpage.com/reviews")

# %%
request=url.text

# %%
from bs4 import BeautifulSoup as Soup

# %%
soup_book=Soup(request,'html.parser')

# %%
soup_book.title.text
# Out:
# 'Book Reviews | BookPage'

# %%
book=soup_book.findAll("div",{"class":"bp-block article-info"})

# %%
first_book=book[0]

# %%
first_book.find("h4",{"class":"italic"}).text.replace("\n","").strip() #name
# Out:
# '★ Fight Night'

# %%
first_book.find("p",{"class":"sans bold"}).text.strip()    #author name
# Out:
# 'Miriam Toews'

# %%
first_book.find('p',{"class":"genre-links hidden-phone"}).text.replace("\n","")             #genre
# Out:
# 'Fiction / Family Drama'

# %%
first_book.find("p",{"class":"excerpt"}).text.strip()                           #review
# Out:
# 'Miriam Toews’ Fight Night is a wonder, a warmhearted and inventive portrait of women who never back down.'

# %%
name=[]
author=[]
genre=[]
review=[]
for i in book:
    name.append(i.find("h4",{"class":"italic"}))   #name 
    author.append(i.find("p",{"class":"sans bold"}).text.strip())    #author name
    genre.append(i.find('p',{"class":"genre-links hidden-phone"}).text.replace("\n","") ) #genre
    review.append(i.find("p",{"class":"excerpt"}).text)                         #review

# %%
data=list(zip(name,author,genre,review))

# %%
import pandas as pd
df=pd.DataFrame(data,columns=["Book Name","Author Name","Genre","Book Review"])
df.head()
# Out:
#                                     Book Name        Author Name  \
# 0            [\n, [ , [★ ], Fight Night], \n]       Miriam Toews
# 1                        [\n, [Reprieve], \n]  James Han Mattson
# 2             [\n, [ , [★ ], Crossroads], \n]   Jonathan Franzen
# 3  [\n, [ , [★ ], The Neighbor's Secret], \n]  L. Allison Heller
# 4                           [\n, [Taste], \n]      Stanley Tucci
#
#                                  Genre  \
# 0               Fiction / Family Drama
# 1  Fiction / Literary Fiction / Horror
# 2               Fiction / Family Drama
# 3        Mystery & Suspense / Thriller
# 4           Nonfiction / Memoir / Food
#
#                                          Book Review
# 0  \nMiriam Toews’ Fight Night is a wonder, a war...
# 1  \nAt some point while reading James Han Mattso...
# 2  \nBy turns funny and terrifying, Jonathan Fran...
# 3  \nCottonwood Estates seems like an idyllic nei...
# 4  \nLike the enormous layered pasta pie that sta...

# %% [markdown]
# ###  Q.5. Write a python program to scrape cricket rankings from ‘www.icc-cricket.com’.
# #####  i) Top 10 ODI teams in men’s cricket along with the records for matches, points andrating.

# %%
import requests
from bs4 import BeautifulSoup

# %%
page=requests.get("https://www.icc-cricket.com/rankings/mens/team-rankings/odi")

# %%
page.status_code
# Out:
# 200

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="ICC Ranking for ODI teams International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="ICC Ranking for ODI teams International Cricket Council"/>\n<meta proper
# ...

# %%
soup=BeautifulSoup(page.content)

# %%
team=soup.find_all('span',class_="u-hide-phablet")

# %%
Team=[]
for i in team:
    Team.append(i.text.strip())
Team[:6]
# Out:
# ['New Zealand', 'England', 'Australia', 'India', 'South Africa', 'Pakistan']

# %%
rating=soup.find_all('td',class_="table-body__cell u-text-right rating")

# %%
Rating=[]
for i in rating:
    Rating.append(i.text.strip())
Rating[:6]
# Out:
# ['119', '116', '113', '98', '93', '91']

# %%
point=soup.find_all('td',class_="table-body__cell table-body__cell--position u-text-right")

# %%
position=[]
for i in point:
    position.append(i.text.strip())
position[:6]
# Out:
# ['2', '3', '4', '5', '6', '7']

# %%
import pandas as pd
df=pd.DataFrame({})
df['Position']=position[:10]
df['Team']=Team[:10]
df['Rating']=Rating[:10]

df
# Out:
#   Position          Team Rating
# 0        2   New Zealand    119
# 1        3       England    116
# 2        4     Australia    113
# 3        5         India     98
# 4        6  South Africa     93
# 5        7      Pakistan     91
# 6        8    Bangladesh     84
# 7        9   West Indies     83
# 8       10     Sri Lanka     62
# 9       11   Afghanistan     48

# %% [markdown]
# ### ii) Top 10 ODI Batsmen in men along with the records of their team and rating.

# %%
import requests
from bs4 import BeautifulSoup

# %%
page=requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/odi")

# %%
page.status_code
# Out:
# 200

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="ICC ODI Match Player Rankings International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="ICC ODI Match Player Rankings International Cricket Council"/>\n<meta property="og:image" content=
# ...

# %%
match=BeautifulSoup(page.content)

# %%
country=match.find_all("span",class_="table-body__logo-text")

# %%
team=[]
for i in country:
    team.append(i.text.strip())
team[:9]
# Out:
# ['IND', 'IND', 'NZ', 'AUS', 'ENG', 'AUS', 'WI', 'NZ', 'SA']

# %%
rating=match.find_all('td',class_="table-body__cell u-text-right rating")

# %%
Ratings=[]
for i in rating:
    Ratings.append(i.text)
Ratings[:8]
# Out:
# ['844', '813', '801', '779', '775', '762', '758', '754']

# %%
name=match.find_all("td",class_="table-body__cell name")

# %%
batsmen=[]
for i in name:
    batsmen.append(i.text.strip())
batsmen[:6]
# Out:
# ['Virat Kohli',
#  'Rohit Sharma',
#  'Ross Taylor',
#  'Aaron Finch',
#  'Jonny Bairstow',
#  'David Warner']

# %%
rank=match.find_all("td",class_="table-body__cell table-body__cell--position u-text-right")

# %%
position=[]
for i in rank:
    position.append(i.text.strip())
position[:2]
# Out:
# ['2', '3']

# %%
import pandas as pd
Odi=pd.DataFrame({})
Odi['Position']=position
Odi['Batsmen Name']=batsmen
Odi['Team']=team
Odi['Rating']=Ratings

Odi.head()
# Out:
#   Position    Batsmen Name Team Rating
# 0        2     Virat Kohli  IND    844
# 1        3    Rohit Sharma  IND    813
# 2        4     Ross Taylor   NZ    801
# 3        5     Aaron Finch  AUS    779
# 4        6  Jonny Bairstow  ENG    775

# %% [markdown]
# ####  iii) Top 10 ODI bowlers along with the records of their team andrating.

# %%
import requests
from bs4 import BeautifulSoup

# %%
page=requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling")

# %%
page.status_code
# Out:
# 200

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="Live Cricket Scores & News International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="Live Cricket Scores & News International Cricket Council"/>\n<meta property="og:image" content="https://www.icc-cricket.com/resources/ver/i/elements/defa
# ...

# %%
odi=BeautifulSoup(page.content)

# %%
pos=odi.find_all("td",class_="table-body__cell table-body__cell--position u-text-right")

# %%
position=[]
for i in pos:
    position.append(i.text.strip())
position[:9]
# Out:
# ['2', '3', '4', '5', '6', '7', '8', '9', '10']

# %%
bow=odi.find_all("td",class_="table-body__cell rankings-table__name name")

# %%
bowler=[]
for i in bow:
    bowler.append(i.text.strip())
bowler[:6]
# Out:
# ['Josh Hazlewood',
#  'Mujeeb Ur Rahman',
#  'Chris Woakes',
#  'Mehedi Hasan',
#  'Matt Henry',
#  'Jasprit Bumrah']

# %%
team=odi.find_all("td",class_="table-body__cell nationality-logo rankings-table__team")

# %%
Team=[]
for i in team:
    Team.append(i.text.strip())
Team[:6]
# Out:
# ['AUS', 'AFG', 'ENG', 'BAN', 'NZ', 'IND']

# %%
rating=odi.find_all('td',class_="table-body__cell rating")

# %%
Rating=[]
for i in rating:
    Rating.append(i.text.strip())
Rating[:6]
# Out:
# ['709', '708', '700', '692', '691', '679']

# %%
record=odi.find_all('td',class_="table-body__cell u-text-right u-hide-phablet")

# %%
Record=[]
for i in record:
    Record.append(i.text.strip())
Record[:6]
# Out:
# ['733 v England, 26/01/2018',
#  '712 v Ireland, 24/01/2021',
#  '711 v Sri Lanka, 04/07/2021',
#  '725 v Sri Lanka, 25/05/2021',
#  '691 v Bangladesh, 26/03/2021',
#  '841 v West Indies, 01/11/2018']

# %%
Bowler=pd.DataFrame({})
Bowler['Position']=position
Bowler['Bowler Name']=bowler
Bowler['Rating']=Rating
Bowler['Career Best Rating']=Record

Bowler[:6]
# Out:
#   Position       Bowler Name Rating             Career Best Rating
# 0        2    Josh Hazlewood    709      733 v England, 26/01/2018
# 1        3  Mujeeb Ur Rahman    708      712 v Ireland, 24/01/2021
# 2        4      Chris Woakes    700    711 v Sri Lanka, 04/07/2021
# 3        5      Mehedi Hasan    692    725 v Sri Lanka, 25/05/2021
# 4        6        Matt Henry    691   691 v Bangladesh, 26/03/2021
# 5        7    Jasprit Bumrah    679  841 v West Indies, 01/11/2018

# %% [markdown]
# ### 6. Write a python program to scrape cricket rankings from ‘www.icc-cricket.com’. You have toscrape:
# #### i) Top 10 ODI teams in women’s cricket along with the records for matches, points andrating.

# %%
import requests
from bs4 import BeautifulSoup

# %%
page=requests.get("https://www.icc-cricket.com/rankings/womens/team-rankings/odi")

# %%
page.status_code
# Out:
# 200

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="ICC Ranking for ODI teams International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="ICC Ranking for ODI teams International Cricket Council"/>\n<meta property="og:image" content="https://w
# ...

# %%
women=BeautifulSoup(page.content)

# %%
pos=women.find_all("td",class_="table-body__cell table-body__cell--position u-text-right")

# %%
position=[]
for i in pos:
    position.append(i.text.strip())
position
# Out:
# ['2', '3', '4', '5', '6', '7', '8', '9', '10']

# %%
name=women.find_all("td",class_="table-body__cell rankings-table__team")

# %%
team=[]
for i in name:
    team.append(i.text.strip())
team[:6]
# Out:
# ['England\nENG',
#  'South Africa\nSA',
#  'India\nIND',
#  'New Zealand\nNZ',
#  'West Indies\nWI',
#  'Pakistan\nPAK']

# %%
rating=women.find_all('td',class_="table-body__cell u-text-right rating")

# %%
Rating=[]
for i in rating:
    Rating.append(i.text.strip())
Rating[:6]
# Out:
# ['119', '117', '113', '92', '85', '75']

# %%
import pandas as pd
df=pd.DataFrame({})
df['Position']=position
df['Team']=team
df['Rating']=Rating

df
# Out:
#   Position              Team Rating
# 0        2      England\nENG    119
# 1        3  South Africa\nSA    117
# 2        4        India\nIND    113
# 3        5   New Zealand\nNZ     92
# 4        6   West Indies\nWI     85
# 5        7     Pakistan\nPAK     75
# 6        8   Bangladesh\nBAN     61
# 7        9     Sri Lanka\nSL     47
# 8       10      Ireland\nIRE     13

# %% [markdown]
# #### ii) Top 10 women’s ODI players along with the records of their team and rating.

# %%
page=requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi")

# %%
page.status_code
# Out:
# 200

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="ICC ODI Match Player Rankings International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="ICC ODI Match Player Rankings International Cricket Council"/>\n<meta property="og:image" content=
# ...

# %%
soup=BeautifulSoup(page.content)

# %%
pos=soup.find_all("td",class_="table-body__cell table-body__cell--position u-text-right")

# %%
position=[]
for i in pos:
    position.append(i.text.strip())
position[:3]
# Out:
# ['2',
#  '3',
#  '4\n        \n\n\n\nThis player has moved up in the rankings since the previous rankings update']

# %%
play=soup.find_all("td",class_="table-body__cell name")

# %%
player=[]
for i in play:
    player.append(i.text.strip())
player[:3]
# Out:
# ['Alyssa Healy', 'Mithali Raj', 'Tammy Beaumont']

# %%
team=soup.find_all("span",class_="table-body__logo-text")

# %%
Team=[]
for i in team:
    Team.append(i.text.strip())
Team[:3]
# Out:
# ['AUS', 'IND', 'ENG']

# %%
ret=soup.find_all("td",class_="table-body__cell u-text-right rating")

# %%
rating=[]
for i in ret:
    rating.append(i.text.strip())
rating[:3]
# Out:
# ['750', '738', '728']

# %%
import pandas as pd
dj=pd.DataFrame({})
dj['Position']=position
dj['Team']=Team
dj['Rating']=rating

dj[:10]
# Out:
#                                             Position Team Rating
# 0                                                  2  AUS    750
# 1                                                  3  IND    738
# 2  4\n        \n\n\n\nThis player has moved up in...  ENG    728
# 3  5\n        \n\n\n\nThis player has moved down ...   NZ    717
# 4  6\n        \n\n\n\nThis player has moved down ...  IND    710
# 5  7\n        \n\n\n\nThis player has moved down ...  AUS    699
# 6  8\n        \n\n\n\nThis player has moved up in...  AUS    690
# 7  9\n        \n\n\n\nThis player has moved down ...  ENG    674
# 8  10\n        \n\n\n\nThis player has moved up i...   SA    672
# 9  2\n        \n\n\n\nThis player has moved up in...  IND    727

# %% [markdown]
# #### iii) Top 10 women’s ODI all-rounder along with the records of their team andrating.

# %%
page=requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder")

# %%
page.status_code
# Out:
# 200

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="Live Cricket Scores & News International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="Live Cricket Scores & News International Cricket Council"/>\n<meta property="og:image" content="https://www.icc-cricket.com/resources/ver/i/elements/defa
# ...

# %%
bestplayer=BeautifulSoup(page.content)

# %%
pos=bestplayer.find_all("td",class_="table-body__cell table-body__cell--position u-text-right")

# %%
position=[]
for i in pos:
    position.append(i.text.strip())
position[:3]
# Out:
# ['2\n        \n\n\n\nThis player has moved up in the rankings since the previous rankings update',
#  '3\n        \n\n\n\nThis player has moved down in the rankings since the previous rankings update',
#  '4']

# %%
play=bestplayer.find_all("td",class_="table-body__cell rankings-table__name name")

# %%
player=[]
for i in play:
    player.append(i.text.strip())
player[:6]
# Out:
# ['Natalie Sciver',
#  'Ellyse Perry',
#  'Stafanie Taylor',
#  'Deepti Sharma',
#  'Ashleigh Gardner',
#  'Dane van Niekerk']

# %%
team=bestplayer.find_all("td",class_="table-body__cell nationality-logo rankings-table__team")

# %%
Team=[]
for i in team:
    Team.append(i.text.strip())
Team[:6]
# Out:
# ['ENG', 'AUS', 'WI', 'IND', 'AUS', 'SA']

# %%
ret=bestplayer.find_all("td",class_="table-body__cell rating")

# %%
Rating=[]
for i in ret:
    Rating.append(i.text.strip())
Rating[:6]
# Out:
# ['372', '365', '322', '299', '275', '274']

# %%
record=bestplayer.find_all('td',class_="table-body__cell u-text-right u-hide-phablet")

# %%
Record=[]
for i in record:
    Record.append(i.text.strip())
Record[:6]
# Out:
# ['391 v New Zealand, 16/09/2021',
#  '548 v West Indies, 11/09/2019',
#  '559 v New Zealand, 10/10/2013',
#  '397 v South Africa, 09/10/2019',
#  '275 v India, 26/09/2021',
#  '421 v Sri Lanka, 11/02/2019']

# %%
AllRounder=pd.DataFrame({})
AllRounder['Position']=position
AllRounder['Player Name']=player
AllRounder['Team Name']=Team
AllRounder['Rating']=Rating
AllRounder['Career Best Rating']=Record

AllRounder[:10]
# Out:
#                                             Position       Player Name  \
# 0  2\n        \n\n\n\nThis player has moved up in...    Natalie Sciver
# 1  3\n        \n\n\n\nThis player has moved down ...      Ellyse Perry
# 2                                                  4   Stafanie Taylor
# 3                                                  5     Deepti Sharma
# 4  6\n        \n\n\n\nThis player has moved up in...  Ashleigh Gardner
# 5  7\n        \n\n\n\nThis player has moved up in...  Dane van Niekerk
# 6  8\n        \n\n\n\nThis player has moved down ...     Jess Jonassen
# 7  This player has moved down in the rankings sin...   Katherine Brunt
# 8  10\n        \n\n\n\nThis player has moved up i...    Jhulan Goswami
# 9  11\n        \n\n\n\nThis player has moved down...     Sophie Devine
#
#   Team Name Rating              Career Best Rating
# 0       ENG    372   391 v New Zealand, 16/09/2021
# 1       AUS    365   548 v West Indies, 11/09/2019
# ...

# %% [markdown]
# ### 7. Write a python program to scrape details of all the mobile phones under Rs. 20,000 listed on Amazon.in. The scraped data should include Product Name, Price, Image URL and Average Rating.

# %%
page=requests.get("https://www.amazon.in/s?k=mobile+under+20000&rh=n%3A976419031%2Cp_36%3A1318506031&dc&qid=1633507060&rnid=1318502031&ref=sr_nr_p_36_4")

# %%
page.status_code
# Out:
# 200

# %%
page.content
# Out:
# b'<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completion.amazon.com">\n<!-- sp:end-feature:cs-optimization -->\n\n<!-- sp:feature:aui-assets -->\n<link rel="stylesheet" href="https://images-eu.ssl-images-amazon.com/images/I/11EIQ5IGqaL._RC|01ZTHTZObnL.css,41jsiPzxYxL.css,31qGOnSAToL.css,013z33uKh2L.css,017DsKjNQJL.css,0131vqwP5UL.css,41EWOOlBJ9L.css,11TIuySqr6L.css,01ElnPiDxWL.css,11bGSgD5pDL.css,01Dm5eKVxwL.css,01IdKcBuAdL.css,01y-XAlI+2L.css,21N4kUH7pxL.css,01oDR3IULNL.css,41-PwE7+H0L.css,21j0IlW7xKL.css,01XPHJk60-L.css,116uEeuY3+L
# ...

# %%
mobile=BeautifulSoup(page.content)

# %%
print(mobile.prettify())
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:end-feature:head-start -->
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
#   <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
#   <link href="https://completion.amazon.com" rel="dns-prefetch"/>
#   <!-- sp:end-feature:cs-optimization -->
#   <!-- sp:feature:aui-assets -->
# ...

# %%
name=mobile.find_all("span",class_="a-size-medium a-color-base a-text-normal")

# %%
mbname=[]
for i in name:
    mbname.append(i.text.strip())
mbname[:10]
# Out:
# ['OPPO A74 5G (Fantastic Purple,6GB RAM,128GB Storage) - 5G Android Smartphone | 5000 mAh Battery | 18W Fast Charge | 90Hz LCD Display',
#  'Redmi 9 Power (Mighty Black 4GB RAM 64GB Storage) - 6000mAh Battery |FHD+ Screen | 48MP Quad Camera | Alexa Hands-Free Capable',
#  'Redmi Note 10S (Frost White, 6GB RAM, 64GB Storage) - Super Amoled Display | 64 MP Quad Camera | Alexa Built in',
#  'OPPO A74 5G (Fluid Black,6GB RAM,128GB Storage) - 5G Android Smartphone | 5000 mAh Battery | 18W Fast Charge | 90Hz LCD Display',
#  'Redmi Note 10 Pro Max (Dark Night, 6GB RAM, 128GB Storage) -108MP Quad Camera | 120Hz Super Amoled Display',
#  'OPPO A31 (Mystery Black, 6GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Samsung Galaxy M31 (Ocean Blue, 8GB RAM, 128GB Storage) 6 Months Free Screen Replacement for Prime',
#  'Redmi 9 Prime (Sunrise Flare, 4GB RAM, 64GB Storage)- Full HD+ Display & AI Quad Camera',
# ...

# %%
price=mobile.find_all('span',class_="a-price-whole")

# %%
Price=[]
for i in price:
    Price.append(i.text.strip())
Price[:10]
# Out:
# ['15,990',
#  '10,499',
#  '12,999',
#  '15,990',
#  '19,499',
#  '11,490',
#  '16,999',
#  '9,999',
#  '14,499',
#  '19,999']

# %%
rating=mobile.find_all('span',class_="a-icon-alt")

# %%
Rating=[]
for i in rating:
    Rating.append(i.text.strip())
Rating[:10]
# Out:
# ['4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.3 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.4 out of 5 stars']

# %%
print(len(Price),len(mbname),len(Rating))
# Out:
# 24 24 28

# %%
df=pd.DataFrame({})
df['Product Name']=mbname[:22]
df['Average Rating']=Rating[:22]
df['Mobile Price']=Price[:22]

df
# Out:
#                                          Product Name      Average Rating  \
# 0   OPPO A74 5G (Fantastic Purple,6GB RAM,128GB St...  4.2 out of 5 stars
# 1   Redmi 9 Power (Mighty Black 4GB RAM 64GB Stora...  4.2 out of 5 stars
# 2   Redmi Note 10S (Frost White, 6GB RAM, 64GB Sto...  4.1 out of 5 stars
# 3   OPPO A74 5G (Fluid Black,6GB RAM,128GB Storage...  4.2 out of 5 stars
# 4   Redmi Note 10 Pro Max (Dark Night, 6GB RAM, 12...  4.1 out of 5 stars
# 5   OPPO A31 (Mystery Black, 6GB RAM, 128GB Storag...  4.2 out of 5 stars
# 6   Samsung Galaxy M31 (Ocean Blue, 8GB RAM, 128GB...  4.2 out of 5 stars
# 7   Redmi 9 Prime (Sunrise Flare, 4GB RAM, 64GB St...  4.3 out of 5 stars
# 8   realme narzo 30 (Racing Blue, 6GB RAM, 128GB S...  4.1 out of 5 stars
# 9   Samsung Galaxy M51 (Celestial Black, 6GB RAM, ...  4.4 out of 5 stars
# 10  OPPO A31 (Fantasy White, 4GB RAM, 64GB Storage...  4.2 out of 5 stars
# 11  Samsung Galaxy M32 (Light Blue, 6GB RAM, 128GB...  4.2 out of 5 stars
# ...

# %% [markdown]
# 8. Write a python program to extract information about the local weather from the National Weather Service website of USA, https://www.weather.gov/ for the city, San Francisco. You need to extract data about 7 day extended forecast display for the city. The data should include period, short description, temperature and description

# %%
import requests
from bs4 import BeautifulSoup

# %%
page=requests.get('https://forecast.weather.gov/MapClick.php?lat=37.777120000000025&lon=-122.41963999999996#.YVws0dpBxPY')

# %%
page.status_code
# Out:
# 200

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html class="no-js">\n    <head>\n        <!-- Meta -->\n        <meta name="viewport" content="width=device-width">\n        <link rel="schema.DC" href="http://purl.org/dc/elements/1.1/" /><title>National Weather Service</title><meta name="DC.title" content="National Weather Service" /><meta name="DC.description" content="NOAA National Weather Service National Weather Service" /><meta name="DC.creator" content="US Department of Commerce, NOAA, National Weather Service" /><meta name="DC.date.created" scheme="ISO8601" content="" /><meta name="DC.language" scheme="DCTERMS.RFC1766" content="EN-US" /><meta name="DC.keywords" content="weather, National Weather Service" /><meta name="DC.publisher" content="NOAA\'s National Weather Service" /><meta name="DC.contributor" content="National Weather Service" /><meta name="DC.rights" content="http://www.weather.gov/disclaimer.php" /><meta name="rating" content="General" /><meta name="robots" content="index,follow" />\n\n      
# ...

# %%
usa=BeautifulSoup(page.content)

# %%
description=usa.find_all('p',class_="short-desc")

# %%
des=[]
for i in description:
    des.append(i.text.strip())
des
# Out:
# ['Mostly Cloudy',
#  'Mostly Cloudythen PartlySunny andBreezy',
#  'Mostly Cloudy',
#  'Mostly Cloudy',
#  'Mostly Cloudy',
#  'Slight ChanceRain andBreezy',
#  'Partly Cloudy',
#  'Sunny',
#  'Mostly Clear']

# %%
perid=usa.find_all('p',class_="period-name")

# %%
Perid=[]
for i in perid:
    Perid.append(i.text.strip())
Perid
# Out:
# ['Overnight',
#  'Wednesday',
#  'WednesdayNight',
#  'Thursday',
#  'ThursdayNight',
#  'Friday',
#  'FridayNight',
#  'Saturday',
#  'SaturdayNight']

# %%
temp=usa.find_all('p',class_="temp temp-low")
#temp=usa.find_all('p',class_="temp temp-high")

# %%
Temp=[]
for i in temp:
    Temp.append(i.text.strip())
Temp
# Out:
# ['Low: 56 °F', 'Low: 55 °F', 'Low: 54 °F', 'Low: 52 °F', 'Low: 54 °F']

# %%
temp1=usa.find_all('p',class_="temp temp-high")

# %%
Temp1=[]
for i in temp:
    Temp1.append(i.text.strip())
Temp1
# Out:
# ['Low: 56 °F', 'Low: 55 °F', 'Low: 54 °F', 'Low: 52 °F', 'Low: 54 °F']

# %%
short=usa.find_all('div',class_="row row-odd row-forecast")

# %%
Short=[]
for i in short:
    Short.append(i.text.strip())
Short
# Out:
# ['OvernightMostly cloudy, with a low around 56. West wind around 13 mph.',
#  'Wednesday NightMostly cloudy, with a low around 55. West wind 13 to 17 mph, with gusts as high as 23 mph.',
#  'Thursday NightMostly cloudy, with a low around 54. West wind 13 to 16 mph, with gusts as high as 22 mph.',
#  'Friday NightPartly cloudy, with a low around 52.',
#  'Saturday NightMostly clear, with a low around 54.',
#  'Sunday NightMostly clear, with a low around 54.',
#  'Monday NightMostly clear, with a low around 52. Breezy.']

# %%
import pandas as pd
USA=pd.DataFrame({})
USA['Period']=Perid[:5]
USA['Short Description']=des[:5]
USA['Temperature']=Temp[:5]
USA['Description']=Short[:5]

USA.head()
# Out:
#            Period                        Short Description Temperature  \
# 0       Overnight                            Mostly Cloudy  Low: 56 °F
# 1       Wednesday  Mostly Cloudythen PartlySunny andBreezy  Low: 55 °F
# 2  WednesdayNight                            Mostly Cloudy  Low: 54 °F
# 3        Thursday                            Mostly Cloudy  Low: 52 °F
# 4   ThursdayNight                            Mostly Cloudy  Low: 54 °F
#
#                                          Description
# 0  OvernightMostly cloudy, with a low around 56. ...
# 1  Wednesday NightMostly cloudy, with a low aroun...
# 2  Thursday NightMostly cloudy, with a low around...
# 3   Friday NightPartly cloudy, with a low around 52.
# 4  Saturday NightMostly clear, with a low around 54.

# %% [markdown]
# #### 9. Write a python program to scrape fresher job listings from ‘https://internshala.com/’. It should include job title,company name, CTC, and apply date.

# %%
import requests
from bs4 import BeautifulSoup

# %%
page=requests.get("https://internshala.com/fresher-jobs")

# %%
page.status_code
# Out:
# 200

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://ogp.me/ns#" xmlns:fb="https://www.facebook.com/2008/fbml">\n    <head>\n        <meta http-equiv="X-UA-Compatible" content="IE=9" />\n        <meta charset="UTF-8" />\n        <meta name="viewport" content="width=device-width, initial-scale=1.0 user-scalable=0" />\n        <meta property="fb:app_id" content="272234782795210" />\n        <meta property="og:type" content="article" />\n                    <meta property="og:image:width" content="1200" />\n            <meta property="og:image:height" content="630" />\n                    <meta name="twitter:site" content="@Internshala" />\n                    <meta name="twitter:card" content="summary_large_image" />\n        \n        <meta name="twitter:creator" content="@internshala" />\n                <meta name="theme-color" content="#ffffff" />\n        <meta name="msapplication-navbutton-color" content="#ffffff"/>\n        <meta name="format-detection"
# ...

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="https://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta content="IE=9" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0 user-scalable=0" name="viewport"/>
# <meta content="272234782795210" property="fb:app_id"/>
# <meta content="article" property="og:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="630" property="og:image:height"/>
# <meta content="@Internshala" name="twitter:site"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@internshala" name="twitter:creator"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="#ffffff" name="msapplication-navbutton-color"/>
# <meta content="telephone=no" name="format-detection"/>
# <link as="font" crossorigin="" href="/static/fonts/Inter.woff2?v=3.11" rel="preload" type="font/woff2"/>
# ...

# %%
job_title=soup.find_all("div",class_="heading_4_5 profile")

# %%
title=[]
for i in job_title:
    title.append(i.text.strip())
title[:10]
# Out:
# ['Business Development Executive',
#  'Management Trainee - Sales',
#  'Sales Development Representative',
#  'Business Development Officer (Sales)',
#  'Junior Web Developer',
#  'Engineer - Trainee',
#  'Social Media Marketing Associate',
#  'Flutter Developer',
#  'Full Stack Developer',
#  'Golang Developer']

# %%
company=soup.find_all("p",id="location_names")

# %%
name=[]
for i in company:
    name.append(i.text.strip())
name[:10]
# Out:
# ['Ahmedabad, Bhubaneswar, Delhi, Kolkata, Pune, Rohtak, Hubli, Bangalore, Mumbai, Jaipur, Noida, Raipur, Nagpur, Ludiana',
#  'Delhi, Salem, Kanpur',
#  'Remote',
#  'Ahmedabad',
#  'Ahmedabad, Bhavnagar, Chandigarh, Delhi, Gandhinagar, Gurgaon, Jamnagar, Mehsana, Rajkot, Surat, Udaipur, Surendranagar, Vadodara, Mumbai, Jaipur',
#  'Gurgaon',
#  'Remote',
#  'Sancoale',
#  'Delhi, Gurgaon, Noida',
#  'Remote']

# %%
print(len(title),len(name))
# Out:
# 40 40

# %%
import pandas as pd
jobs=pd.DataFrame({})
jobs['Job TItle']=title
jobs['Company Name']=name

jobs.head()
# Out:
#                               Job TItle  \
# 0        Business Development Executive
# 1            Management Trainee - Sales
# 2      Sales Development Representative
# 3  Business Development Officer (Sales)
# 4                  Junior Web Developer
#
#                                         Company Name
# 0  Ahmedabad, Bhubaneswar, Delhi, Kolkata, Pune, ...
# 1                               Delhi, Salem, Kanpur
# 2                                             Remote
# 3                                          Ahmedabad
# 4  Ahmedabad, Bhavnagar, Chandigarh, Delhi, Gandh...

# %% [markdown]
# ### 10. Write a python program to scrape house details from https://www.nobroker.in/ for any location. It should include house title, location, area, emi and price

# %%
import pandas as pd 
from bs4 import BeautifulSoup

# %%
import requests

# %%
page=requests.get('https://www.nobroker.in/flats-for-sale-in-mumbai_mumbai')

# %%
page.status_code
# Out:
# 200

# %%
page.content
# Out:
# b'\n          <!DOCTYPE html><html lang="en"><head>\n          <meta property="fb:pages" content="794951570520699" />\n          <link rel="canonical" href="https://www.nobroker.in/flats-for-sale-in-mumbai_mumbai" />\n          \n          \n          <link rel="next" href="https://www.nobroker.in/flats-for-sale-in-mumbai_mumbai-page-2"/>\n          \n           \n          <link rel="dns-prefetch" href="//www.googletagmanager.com">\n          <link rel="dns-prefetch" href="//www.google-analytics.com">\n          <link rel="dns-prefetch" href="//assets.nobroker.in">\n          <link rel="dns-prefetch" href="//images.nobroker.in">\n          <link rel="shortcut icon" id="favicon" href="//assets.nobroker.in/static/img/favicon.png"/>\n          <link rel="apple-touch-icon" href="https://images.nobroker.in/static/img/fav64.png">\n          <meta charset="utf-8"/><meta charset="UTF-8"/>\n          <meta name="google-play-app" content="app-id=com.nobroker.app&referrer=utm_source%3Dnobroker
# ...

# %%
soup=BeautifulSoup(page.content)

# %%
titles=soup.find_all('h2',class_="heading-6 font-semi-bold nb__1AShY")

# %%
house=[]
for i in titles:
    house.append(i.text)
house
# Out:
# ['3 BHK Apartment  For Sale  In Rna Royale Park In Kandivali West ',
#  '2 BHK Flat  For Sale  In Galaxy Apartments In Kurla East ',
#  '1 BHK Apartment  For Sale  In Lok Raunak In Andheri East ',
#  '1 RK Flat  For Sale  In Chatrapati Shivaji Raje Complex In Kandivali West ',
#  '1 BHK Flat  For Sale  In Akash  Apartments In Santacruz East ',
#  '2 BHK Apartment  For Sale  In Raheja Nest Chs In Powai ',
#  '2 BHK Flat  For Sale  In Diamond Isle 2 In Goregaon East ',
#  '3 BHK Flat  For Sale  In Pratima Chs In Andheri East ',
#  '3 BHK Apartment  For Sale  In Imperial Height In Goregaon West ',
#  '2 BHK Apartment  For Sale  In Cci Rivali Park Wintergreen  In Borivali East ']

# %%
location=soup.find_all('div',class_="nb__2CMjv")

# %%
locations=[]
for i in location:
    locations.append(i.text)
locations
# Out:
# ['Rna Royale Park\xa0 mg road, behind RNA Regancy, ,Kandivali West, Mumbai, Maharashtra, INDIA',
#  'Kurla East, Mumbai, Maharashtra, INDIA.',
#  'Lok Raunak\xa0 Nest to 7 hills hospital, Marol Maroshi Rd, Bori Colony, Shivaji Nagar JJC, Marol',
#  'Chatrapati Shivaji Raje Complex',
#  'yeshwant nagar Vakola',
#  'Raheja Nest CHS\xa0 Opp Nahar Amrit Shakti, Chandivali  Farm road Powai ',
#  'Royal Palms, Aarey Colony, Goregaon East, Mumbai, Maharashtra 400063, India',
#  'Sahar Road,  Near Koldongri Fish Market',
#  'Imperial Height\xa0  goregaon bus depot,Best Colony Rd, Best Nagar,',
#  'Cci Rivali Park Wintergreen \xa0 Near Maghthane metro Station Near Borivali Railway station ']

# %%
area=soup.find_all('div',class_="nb__3oNyC")

# %%
Area=[]
for i in area:
    Area.append(i.text)
Area
# Out:
# ['1,670 sqft',
#  '920 sqft',
#  '570 sqft',
#  '340 sqft',
#  '665 sqft',
#  '850 sqft',
#  '785 sqft',
#  '1,100 sqft',
#  '2,030 sqft',
#  '1,000 sqft']

# %%
emi=soup.find_all('div',id="roomType")

# %%
EMI=[]
for i in emi:
    EMI.append(i.text)
EMI
# Out:
# ['₹1.78 Lacs/Month',
#  '₹57,314/Month',
#  '₹58,460/Month',
#  '₹26,937/Month',
#  '₹65,911/Month',
#  '₹1.09 Lacs/Month',
#  '₹41,266/Month',
#  '₹1.4 Lacs/Month',
#  '₹2.01 Lacs/Month',
#  '₹1.23 Lacs/Month']

# %%
print(len(EMI),len(Area),len(house),len(locations))
# Out:
# 10 10 10 10

# %%
print(len(EMI),len(Area),len(house),len(locations))
# Out:
# 10 10 10 10

# %%
import pandas as pd
df=pd.DataFrame({})
df['House Title']=house
df['Locations']=locations
df['Area']=Area
df['EMI']=EMI

df
# Out:
#                                          House Title  \
# 0  3 BHK Apartment  For Sale  In Rna Royale Park ...
# 1  2 BHK Flat  For Sale  In Galaxy Apartments In ...
# 2  1 BHK Apartment  For Sale  In Lok Raunak In An...
# 3  1 RK Flat  For Sale  In Chatrapati Shivaji Raj...
# 4  1 BHK Flat  For Sale  In Akash  Apartments In ...
# 5  2 BHK Apartment  For Sale  In Raheja Nest Chs ...
# 6  2 BHK Flat  For Sale  In Diamond Isle 2 In Gor...
# 7  3 BHK Flat  For Sale  In Pratima Chs In Andher...
# 8  3 BHK Apartment  For Sale  In Imperial Height ...
# 9  2 BHK Apartment  For Sale  In Cci Rivali Park ...
#
#                                            Locations        Area  \
# 0  Rna Royale Park  mg road, behind RNA Regancy, ...  1,670 sqft
# 1            Kurla East, Mumbai, Maharashtra, INDIA.    920 sqft
# 2  Lok Raunak  Nest to 7 hills hospital, Marol Ma...    570 sqft
# 3                    Chatrapati Shivaji Raje Complex    340 sqft
# ...
